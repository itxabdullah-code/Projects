# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as splt

# %%
value_x= [10,20,50,3,5,6,7,45,3,40]
value_y= [1,2,34,45,3,6,7,2,4,5]
plt.plot(value_x, value_y)      #plot is use to plot or create a graph
plt.axis([0,50, 0,50])          #axix is use to create a limit of graph
plt.title("Testing Graph")      #title is use to create a name of table
plt.xlabel("X -Axis")           #xlabel is use to create a name of graph for x-axis
plt.ylabel("Y -Axis")           #ylabel is use to create a name of graph for y-axis
plt.show()                      #show is use to show the graph it's not mandatory in jupyter notebook but for other PY IDEs

# %%
value_x= [10,20,50,3,5,6,7,45,3,40]
value_y= [1,2,34,45,3,6,7,2,4,5]
plt.plot(value_x, value_y,color='y')      #plot is use to plot or create a graph
plt.axis([0,50, 0,50])          #axix is use to create a limit of graph
plt.title("Testing Graph")      #title is use to create a name of table
plt.xlabel("X -Axis")           #xlabel is use to create a name of graph for x-axis
plt.ylabel("Y -Axis")           #ylabel is use to create a name of graph for y-axis
plt.show()

# %%
``'.'``         point marker
``','``         pixel marker
``'o'``         circle marker
``'v'``         triangle_down marker
``'^'``         triangle_up marker
``'<'``         triangle_left marker
``'>'``         triangle_right marker
``'1'``         tri_down marker
``'2'``         tri_up marker
``'3'``         tri_left marker
``'4'``         tri_right marker
``'8'``         octagon marker
``'s'``         square marker
``'p'``         pentagon marker
``'P'``         plus (filled) marker
``'*'``         star marker
``'h'``         hexagon1 marker
``'H'``         hexagon2 marker
``'+'``         plus marker
``'x'``         x marker
``'X'``         x (filled) marker
``'D'``         diamond marker
``'d'``         thin_diamond marker
``'|'``         vline marker
``'_'``         hline marker
=============   ===============================

**Line Styles**

=============    ===============================
character        description
=============    ===============================
``'-'``          solid line style
``'--'``         dashed line style
``'-.'``         dash-dot line style
``':'``          dotted line style
# Out:
#   Cell In[4], line 1
#     ``'.'``         point marker
#     ^
# SyntaxError: invalid syntax

# %%
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
print(y)
# plt.axis(
# plt.plot(x,y,'.')
# plt.plot(x,y,',')
# plt.plot(x,y,'v')
# plt.plot(x,y,'*')
# plt.plot(x,y,'<')
# plt.plot(x,y,'>')
# plt.plot(x,y,'1')
# plt.plot(x,y,'3')
# plt.plot(x,y,'|')
# plt.plot()
plt.plot(x,y,'--',marker='*')
# plt.plot(x, [2,2,2],'ro')
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# ...

# %%
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
# plt.plot(x,y, marker='o')
# plt.plot(x,y, color='g')      # color is use to point to out graph lines with different colors like b,y,r,g...etc.
plt.plot(x,y, "--",marker='*',)       # marker is use to point out with different operators like stars dot circles...etc.

# %%
x=[1,5,10,15,20]
y=[5,10,15,20,25]
plt.title("....Graph....",fontsize='15')
# plt.legend(["Line Info"])
plt.plot(x,y,color='g',marker='*',markersize='9',linestyle='--',linewidth='2')
plt.grid(color='r',linewidth='2',linestyle='-.',label="DATA")
plt.show()

# %% [markdown]
# <h3>Histogram chart</h3>

# %%
x=np.random.randint(1,100,100)
y=np.arange(1,100,(30))
# bins=[5,25,40,60]
# plt.hist(x,y,bins, histtype="barstacked")
plt.hist(x, histtype="bar",rwidth=.9,color='y')
plt.axis([0, 100, 0,20])
# Out:
# (np.float64(0.0), np.float64(100.0), np.float64(0.0), np.float64(20.0))

# %%
x=np.random.randint(1,100,100)
y=np.arange(1,100,(30))
# bins=[5,25,40,60]
# plt.hist(x,y,bins, histtype="barstacked")
plt.hist(x, histtype="bar",rwidth=.9,color='y',orientation="horizontal",align="mid")
plt.axis([0, 100, 0,100])
# Out:
# (np.float64(0.0), np.float64(100.0), np.float64(0.0), np.float64(100.0))

# %%
x=np.random.randint(1,200,100)
y=np.random.randint(1,200,70)
print(len(x))
print(len(y))
# y=np.arange(1,100,(30))
# bins=[5,25,40,60]
# plt.hist(x,y,bins, histtype="barstacked")
plt.hist(x, histtype="bar",rwidth=0.9,color='b')
plt.hist(y, histtype="bar" ,rwidth=.9,color='r')
# plt.axis([0, 100, 0,100])
# Out:
# 100
# 70
# (array([ 5.,  8.,  7.,  2.,  8.,  8.,  8.,  6.,  7., 11.]),
#  array([  4. ,  22.9,  41.8,  60.7,  79.6,  98.5, 117.4, 136.3, 155.2,
#         174.1, 193. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <h3>Bar Graph</h3>

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
plt.bar(name,age,color='k')
# plt.grid("b")
# Out:
# <BarContainer object of 4 artists>

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
plt.title("Bar Graph")
plt.xlabel("AGE")
plt.barh(name,age,color='k',edgecolor="b",linewidth=2, linestyle=":")
# Out:
# <BarContainer object of 4 artists>

# %%
age=[30,28,24,20]
age2=[1,28,14,25]
plt.title("Scater Chart")
plt.xlabel("Horizental")
plt.ylabel("Vertical")
plt.scatter(age,age2, marker="*", vmin=0,vmax=100)
# Out:
# C:\Users\premier\AppData\Local\Temp\ipykernel_1744\309026276.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   plt.scatter(age,age2, marker="*", vmin=0,vmax=100)

# %%
# Sample data
# x = np.random.rand(100)
# y = np.random.rand(100)
# z = np.random.rand(100) * 10 # Values for color mapping
# plt.figure(figsize=(10, 5))


# # Scatter plot without vmin and vmax
# plt.figure(figsize=(10, 5))

# plt.subplot(1, 2, 1)
# plt.scatter(x, y, c=z, cmap='viridis')
# plt.colorbar(label='Z values')
# plt.title('Without vmin/vmax')

# # Scatter plot with vmin and vmax
# plt.subplot(1, 2, 2)
# plt.scatter(x, y, c=z, cmap='viridis', vmin=2, vmax=8)
# plt.colorbar(label='Z values')
# plt.title('With vmin=2, vmax=8')

# plt.tight_layout()
# plt.show()

# %%
data=pd.read_csv("D:\\read me\\PY RESEARCH 2.0\\numpy\\Data.csv")
# print(data)
data=data.fillna(10)
print(data)
# print(type(data))
# print(data["Rating"],data["Sales"])
# Out:
#    ID     Category Region  Sales    Profit  Discount  Rating
# 0   1  Electronics  North   1200       150        50     4.5
# 1   2    Gurniture   West    560       150        50     4.5
# 2   3     Clothing   East   1250  no value        50     4.5
# 3   4    Furniture  South    900        10        50     2.5
# 4   5  Electronics  North   1000       not        50     3.0
# 5   6     Clothing   East   1300       150        50     4.5
# 6   7    Furniture   West   2000        10        50     4.5
# 7   8  Electronics  North   1800       150        50     4.5

# %%
x1=data["Sales"]
x2=data["Rating"]
# print(x1)
# print(x2)

plt.figure(figsize=(8, 5))
plt.title("Scatter Graph")
plt.xlabel("Horizental")
plt.ylabel("Vertical")
plt.scatter(x1,x2,marker="<",color="b",linewidths=4, edgecolors="k")
plt.grid("b",'major')

# %% [markdown]
# <h3>Pie Chart</h3>

# %%
plt.pie([1,3,4,2,5,7])
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3b08e750>,
# ...
#  [Text(1.0888035845986856, 0.1565463323270563, ''),
#   Text(0.831324497960876, 0.7203468463803375, ''),
#   Text(-0.15654644481792448, 1.0888035684249335, ''),
#   Text(-0.9253790575509673, 0.5947046324404104, ''),
#   Text(-1.0005951148291057, -0.4569566896108741, ''),
#   Text(0.5947051656296762, -0.925378714891033, '')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
plt.title("Pie Chart")
plt.xlabel("Data")
plt.ylabel("Value")
plt.pie(age , labels = name)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3ae41d10>,
# ...
#  [Text(0.6628980651351103, 0.8778189763499803, 'Abdullah'),
#   Text(-0.999311911052831, 0.4597561358241333, 'Aziz'),
#   Text(-0.4287641117602496, -1.01299621739987, 'Samee'),
#   Text(0.897816596860321, -0.6355512240584167, 'Rafee')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
plt.title("Pie Chart")
plt.xlabel("Data")
plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, autopct="None")     # explode is use to create a slice as seperate, colors is use to change the color of slices and autopct is use to write down the percentage of slices.
# Out:
# ([<matplotlib.patches.Wedge at 0x22e39d3fd10>,
# ...
#  [Text(0.6628980651351103, 0.8778189763499803, 'Abdullah'),
#   Text(-0.999311911052831, 0.4597561358241333, 'Aziz'),
#   Text(-0.4287641117602496, -1.01299621739987, 'Samee'),
#   Text(1.061055978107652, -0.7511059920690379, 'Rafee')],
#  [Text(0.3615807628009692, 0.4788103507363528, 'None'),
#   Text(-0.545079224210635, 0.25077607408589087, 'None'),
#   Text(-0.2338713336874088, -0.5525433913090199, 'None'),
#   Text(0.6529575249893244, -0.4622190720424848, 'None')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
plt.title("Pie Chart")
plt.xlabel("Data")
plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, autopct="%0.2f%%", startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3eac5c10>,
# ...
#  [Text(-0.6628977791053469, -0.8778191923495402, 'Abdullah'),
#   Text(0.9993120608603421, -0.45975581020695766, 'Aziz'),
#   Text(0.428764264718418, 1.0129961526582787, 'Samee'),
#   Text(-1.061056222848993, 0.7511056463330761, 'Rafee')],
#  [Text(-0.3615806067847346, -0.47881046855429454, '29.41%'),
#   Text(0.5450793059238229, -0.2507758964765223, '27.45%'),
#   Text(0.23387141711913706, 0.5525433559954246, '23.53%'),
#   Text(-0.6529576755993803, 0.46221885928189294, '19.61%')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0.03,0.03,0.03,0.2]
color=['r','g','y','k']
# plt.title("Pie Chart")
# plt.xlabel("Data")
# plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, autopct="Name", startangle=180,radius=1.5,counterclock=True,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3f88be50>,
# ...
#  [Text(-1.0124256989972569, -1.340669311952025, 'Abdullah'),
#   Text(1.5262220565867044, -0.7021725101342626, 'Aziz'),
#   Text(0.6548399679335839, 1.5471213967871893, 'Samee'),
#   Text(-1.5099646248235672, 1.0688811120893775, 'Rafee')],
#  [Text(-0.5604499405163386, -0.7421562262591564, 'Name'),
#   Text(0.8448729241819255, -0.3887026395386096, 'Name'),
#   Text(0.3625006965346624, 0.8564422017929082, 'Name'),
#   Text(-0.8978168039491479, 0.6355509315126027, 'Name')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
edge={"linewidth":3, "width":1, "edgecolor":"k"}
plt.title("Pie Chart")
plt.xlabel("Data")
plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, startangle=180,autopct="%0.2f%%",wedgeprops=edge,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3f8dbe50>,
# ...
#  [Text(-0.6628977791053469, -0.8778191923495402, 'Abdullah'),
#   Text(0.9993120608603421, -0.45975581020695766, 'Aziz'),
#   Text(0.428764264718418, 1.0129961526582787, 'Samee'),
#   Text(-1.061056222848993, 0.7511056463330761, 'Rafee')],
#  [Text(-0.3615806067847346, -0.47881046855429454, '29.41%'),
#   Text(0.5450793059238229, -0.2507758964765223, '27.45%'),
#   Text(0.23387141711913706, 0.5525433559954246, '23.53%'),
#   Text(-0.6529576755993803, 0.46221885928189294, '19.61%')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
edge={"linewidth":3, "width":1, "edgecolor":"k"}
# plt.title("Pie Chart")
# plt.xlabel("Data")
# plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, startangle=180,autopct="%0.2f%%",wedgeprops=edge,shadow=True, rotatelabels=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3f95aa50>,
# ...
#  [Text(-0.6628977791053469, -0.8778191923495402, 'Abdullah'),
#   Text(0.9993120608603421, -0.45975581020695766, 'Aziz'),
#   Text(0.428764264718418, 1.0129961526582787, 'Samee'),
#   Text(-1.061056222848993, 0.7511056463330761, 'Rafee')],
#  [Text(-0.3615806067847346, -0.47881046855429454, '29.41%'),
#   Text(0.5450793059238229, -0.2507758964765223, '27.45%'),
#   Text(0.23387141711913706, 0.5525433559954246, '23.53%'),
#   Text(-0.6529576755993803, 0.46221885928189294, '19.61%')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
edge={"linewidth":3, "width":1, "edgecolor":"k"}
# plt.title("Pie Chart")
# plt.xlabel("Data")
# plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, startangle=180,autopct="%0.2f%%",wedgeprops=edge,shadow=True, rotatelabels=True,frame=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3f9b99d0>,
# ...
#  [Text(-0.6628977791053469, -0.8778191923495402, 'Abdullah'),
#   Text(0.9993120608603421, -0.45975581020695766, 'Aziz'),
#   Text(0.428764264718418, 1.0129961526582787, 'Samee'),
#   Text(-1.061056222848993, 0.7511056463330761, 'Rafee')],
#  [Text(-0.3615806067847346, -0.47881046855429454, '29.41%'),
#   Text(0.5450793059238229, -0.2507758964765223, '27.45%'),
#   Text(0.23387141711913706, 0.5525433559954246, '23.53%'),
#   Text(-0.6529576755993803, 0.46221885928189294, '19.61%')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
edge={"linewidth":3, "width":1, "edgecolor":"k"}
# plt.title("Pie Chart")
# plt.xlabel("Data")
# plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, startangle=180,autopct="%0.2f%%",wedgeprops=edge,shadow=True, rotatelabels=True, labeldistance=1.3)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3fa34850>,
# ...
#  [Text(-0.7834246480335917, -1.0374226818676384, 'Abdullah'),
#   Text(1.1810051628349496, -0.5433477756991317, 'Aziz'),
#   Text(0.5067214037581304, 1.1971772713234201, 'Samee'),
#   Text(-1.2242956417488382, 0.8666603611535493, 'Rafee')],
#  [Text(-0.3615806067847346, -0.47881046855429454, '29.41%'),
#   Text(0.5450793059238229, -0.2507758964765223, '27.45%'),
#   Text(0.23387141711913706, 0.5525433559954246, '23.53%'),
#   Text(-0.6529576755993803, 0.46221885928189294, '19.61%')])

# %%
name=["Abdullah","Aziz","Samee","Rafee"]
age=[30,28,24,20]
seperation=[0,0,0,0.2]
color=['r','g','y','k']
edge={"linewidth":3, "width":1, "edgecolor":"k"}
# plt.title("Pie Chart")
# plt.xlabel("Data")
# plt.ylabel("Value")
plt.pie(age , labels = name, explode=seperation,colors=color, startangle=180,autopct="%0.2f%%",wedgeprops=edge,shadow=True, rotatelabels=True)     
plt.legend()

# %%
plt.pie([1] , colors="b", radius=2.3)
plt.pie([1] , colors="r", radius=2.1)
part=np.ones(20)

color=["k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w"]
plt.pie(part, colors=color, radius=1.9)
plt.pie([1] , colors="y", radius=1.6)
plt.pie([1] , colors="m", radius=1.4)
plt.pie([1] , colors="b", radius=1.2)
plt.pie([1] , colors="k", radius=0.9)
plt.pie([1] , colors="w", radius=0.2,)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3fb51850>],
#  [Text(-0.2199999999999992, -1.9233011600819446e-08, '')])

# %%
part1=np.ones(30)
color1=["k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w","k","w"]
part2=np.ones(15)
color2=["w","k","w","k","w","k","w","k","w","k","w","k","w","k","w"]
part3=np.ones(10)
color3=["w","k","w","k","w","k","w","k","w","k","w"]
part4=np.ones(5)
color4=["k","w","k","w"]

# plt.pie(part2,colors=color2,radius=0.8)
# plt.pie(part3,colors=color3,radius=0.6)
# plt.pie(part4,colors=color4,radius=0.4)
plt.pie(part1,colors=color1,radius=1)
# Out:
# ([<matplotlib.patches.Wedge at 0x22e3fb8b8d0>,
# ...
#  [Text(1.093974083713357, 0.11498132093310277, ''),
#   Text(1.046162154822638, 0.33991873413634466, ''),
#   Text(0.9526279033665705, 0.5500000706612792, ''),
#   Text(0.8174592491392136, 0.7360437323941786, ''),
#   Text(0.6465637011386807, 0.8899187493079641, ''),
#   Text(0.447410275171291, 1.0049000177486065, ''),
#   Text(0.2287028191386328, 1.0759623694711826, ''),
#   Text(-4.8082529002048655e-08, 1.099999999999999, ''),
#   Text(-0.22870304146695908, 1.075962322213823, ''),
#   Text(-0.44741036302244247, 1.0048999786347528, ''),
#   Text(-0.6465639380677015, 0.8899185771689371, ''),
#   Text(-0.8174592696145774, 0.7360437096539864, ''),
#   Text(-0.9526280497967484, 0.5499998170367368, ''),
#   Text(-1.0461621541481756, 0.33991873621212615, ''),
#   Text(-1.0939741083288377, 0.11498108673222909, ''),
#   Text(-1.0939740882248885, -0.11498127800874296, ''),
#   Text(-1.0461620136718623, -0.3399191685533991, ''),
# ...

# %% [markdown]
# <h3>Sub Plot</h3>

# %%
plt.subplot(2,2,1)
plt.hist([1])

plt.subplot(2,2,2)
plt.hist([1,2])

plt.subplot(2,2,3)
plt.hist([1,2,3])

plt.subplot(2,2,4)
plt.hist([2,3,4,5])
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([2. , 2.3, 2.6, 2.9, 3.2, 3.5, 3.8, 4.1, 4.4, 4.7, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.title("Subplots row column and number of element")
plt.subplot(2,3,1)
plt.pie([1])

plt.subplot(2,3,2)
plt.pie([1,2])

plt.subplot(2,3,3)
plt.pie([1,2,3])

plt.subplot(2,3,6)
plt.pie([2,3,4,5,6,1])
          
plt.subplot(2,3,4)
plt.pie([2,3,4,5])



# plt.subplot(2,3,6)
# plt.pie([2,3,4,5,6,7])
# Out:
# ([<matplotlib.patches.Wedge at 0x22e40013450>,
# ...
#  [Text(0.9910657385721545, 0.47727214650388927, ''),
#   Text(-4.8082529002048655e-08, 1.099999999999999, ''),
#   Text(-1.0999999999999959, -9.616505800409723e-08, ''),
#   Text(0.4772723060025268, -0.9910656617616366, '')])

# %%
plt.title("Subplots row column and number of element for pie graph")
plt.subplot(2,3,1)
plt.pie([1])

plt.subplot(2,3,2)
plt.pie([1,2])

plt.subplot(2,3,3)
plt.pie([1,2,3])

plt.subplot(2,3,6)
plt.pie([2,3,4,5,6,1])
          
plt.subplot(2,3,4)
plt.pie([2,3,4,5])


plt.savefig("Pie Chart")
plt.savefig("Pie chart" )
plt.draw()
# plt.subplot(2,3,5)
# plt.pie([2,3,4,6,7])
# plt.bar([1],[2])

# %% [markdown]
# <h3>Image Read</h3>

# %%
img=plt.imread("Pie chart.png")
# print(img)
print(type(img))
print(np.shape(img))
print(np.ndim(img))
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (480, 640, 4)
# 3

# %%
plt.title("Output of ARRAY")
plt.axis("off")
plt.imshow(img)
plt.colorbar()

# %%
"""'mc' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'"""
plt.imshow(img , cmap='BrBG_r')  #cmap is use to change the color of colorbar
plt.imshow(img , cmap='BuPu') 
plt.colorbar()

# %%
#We can change the color of graphs by usign single_channel RGB uses [:,:,0]
sc=img[:,:,2]
# plt.imshow(sc , cmap='BrBG_r')  #cmap is use to change the color of colorbar
plt.imshow(img , cmap='BuPu') 
plt.colorbar()

# %%
img2= plt.imread("D:\\read me\\Best wallpaper\\LostFile_JPG_23835904.jpg")
plt.imshow(img2)

# %%
img2= plt.imread("D:\\read me\\Best wallpaper\\LostFile_JPG_23835904.jpg")
cr=img2[:,:,1]
plt.imshow(cr, cmap= 'Blues_r')

# %%
cr=img2[:,:,1]
img2= plt.imread("D:\\read me\\Best wallpaper\\LostFile_JPG_23835904.jpg")
plt.imshow(cr, cmap= 'CMRmap_r')
plt.colorbar()
